# %%
pip install torch_geometric
# Out:
# Requirement already satisfied: torch_geometric in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (2.3.0)
# Requirement already satisfied: scipy in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch_geometric) (1.10.1)
# Requirement already satisfied: numpy in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch_geometric) (1.23.5)
# Requirement already satisfied: jinja2 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch_geometric) (5.9.4)
# Requirement already satisfied: requests in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch_geometric) (2.28.1)
# Requirement already satisfied: pyparsing in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: tqdm in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from jinja2->torch_geometric) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from requests->torch_geometric) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from requests->torch_geometric) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from scikit-learn->torch_geometric) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from scikit-learn->torch_geometric) (1.2.0)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (1.13.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: torchvision in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (0.14.1)
# Requirement already satisfied: torchaudio in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (0.13.1)
# Requirement already satisfied: typing_extensions in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torch) (4.4.0)
# Requirement already satisfied: numpy in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yeseo\anaconda3\envs\mlchem\lib\site-packages (from requests->torchvision) (1.26.15)

# %%
import os
import h5py
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.data import Data, Dataset, DataLoader
from torch_geometric.nn import global_add_pool
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np

# %%
KEY_CONFIG = {
    "atoms": "elements", 
    "R_coords": "RG", "TS_coords": "TSG", "P_coords": "PG",          
    "R_energy": { "H": "R_H", "G": "R_F", "E": "R_E" },
    "TS_energy": { "H": "TS_H", "G": "TS_F", "E": "TS_E" },
    "P_energy": { "H": "P_H", "G": "P_F", "E": "P_E" }
}
ATOM_MAP = {1: 0, 6: 1, 7: 2, 8: 3, 9: 4}

# %%
class ReactionDataset(Dataset):
    def __init__(self, h5_path, limit=None, transform=None, pre_transform=None):
        super(ReactionDataset, self).__init__(None, transform, pre_transform)
        self.h5_path = h5_path
        if not os.path.exists(h5_path): raise FileNotFoundError(f"File not found: {h5_path}")
        with h5py.File(self.h5_path, 'r') as f:
            self.keys = list(f.keys())
            if limit: self.keys = self.keys[:limit]
            self.len_data = len(self.keys)

    def len(self): return self.len_data

    def get(self, idx):
        with h5py.File(self.h5_path, 'r') as f:
            group = f[self.keys[idx]]
            atoms = group[KEY_CONFIG["atoms"]][()]
            x_indices = [ATOM_MAP.get(int(a), 0) for a in atoms]
            x = F.one_hot(torch.tensor(x_indices, dtype=torch.long), num_classes=5).float()
            
            pos_R = torch.tensor(group[KEY_CONFIG["R_coords"]][()], dtype=torch.float)
            pos_TS = torch.tensor(group[KEY_CONFIG["TS_coords"]][()], dtype=torch.float)
            
            e_R = torch.tensor([group[KEY_CONFIG["R_energy"][k]][()] for k in ["H","G","E"]], dtype=torch.float)
            e_TS = torch.tensor([group[KEY_CONFIG["TS_energy"][k]][()] for k in ["H","G","E"]], dtype=torch.float)
            y_delta = e_TS - e_R

            num_nodes = x.size(0)
            row = torch.arange(num_nodes).repeat_interleave(num_nodes)
            col = torch.arange(num_nodes).repeat(num_nodes)
            mask = row != col
            edge_index = torch.stack([row[mask], col[mask]], dim=0)

            return Data(x=x, pos=pos_R, edge_index=edge_index, y_energy=y_delta, y_pos=pos_TS)

# %%
class GCPNetPlusPlusEncoder(nn.Module):
    def __init__(self, node_dim, hidden_dim):
        super().__init__()
        self.scalar_emb = nn.Linear(node_dim, hidden_dim)
        self.scalar_update = nn.Sequential(
            nn.Linear(hidden_dim * 2 + 1, hidden_dim), nn.SiLU(), nn.Linear(hidden_dim, hidden_dim)
        )
    def forward(self, x, pos, edge_index):
        row, col = edge_index
        h = self.scalar_emb(x)
        dist = (pos[row] - pos[col]).norm(dim=-1, keepdim=True)
        edge_feat = torch.cat([h[row], h[col], dist], dim=-1)
        message = self.scalar_update(edge_feat)
        h_new = torch.zeros_like(h)
        h_new.index_add_(0, row, message)
        return h_new + h

# %%
class DeepGCPLayer(nn.Module):
    """ (기존 동일) """
    def __init__(self, hidden_dim):
        super().__init__()
        self.message_mlp = nn.Sequential(
            nn.Linear(hidden_dim * 2 + 1, hidden_dim), nn.SiLU(), nn.Linear(hidden_dim, hidden_dim)
        )
        self.update_mlp = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim), nn.SiLU(), nn.Linear(hidden_dim, hidden_dim)
        )
        self.norm = nn.LayerNorm(hidden_dim)

    def forward(self, h, pos, edge_index):
        row, col = edge_index
        dist = (pos[row] - pos[col]).norm(dim=-1, keepdim=True)
        edge_feat = torch.cat([h[row], h[col], dist], dim=-1)
        message = self.message_mlp(edge_feat)
        aggr_msg = torch.zeros_like(h)
        aggr_msg.index_add_(0, row, message)
        new_h = self.update_mlp(torch.cat([h, aggr_msg], dim=-1))
        return self.norm(h + new_h)

# %%
class DeepGCPNet(nn.Module):
    """ (기존 동일) """
    def __init__(self, node_dim, hidden_dim, num_layers=3):
        super().__init__()
        # One-hot 벡터를 Dense Vector로 변환하는 Embedding 사용 (표현력 상승)
        self.embedding = nn.Linear(node_dim, hidden_dim) 
        self.layers = nn.ModuleList([DeepGCPLayer(hidden_dim) for _ in range(num_layers)])
        
    def forward(self, x, pos, edge_index):
        h = self.embedding(x)
        for layer in self.layers:
            h = layer(h, pos, edge_index)
        return h

# %%
class SigmoidGating(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.gate_mlp = nn.Sequential(
            nn.Linear(hidden_dim * 2 + 1, hidden_dim), nn.SiLU(),
            nn.Linear(hidden_dim, 1), nn.Sigmoid()
        )
    def forward(self, h, edge_index, pos):
        row, col = edge_index
        dist = (pos[row] - pos[col]).norm(dim=-1, keepdim=True)
        return self.gate_mlp(torch.cat([h[row], h[col], dist], dim=-1))

# %%
class StructureDecoder(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim), nn.SiLU(), nn.Linear(hidden_dim, 1)
        )
    def forward(self, h, edge_index, gate_score):
        row, col = edge_index
        return self.mlp(torch.cat([h[row], h[col]], dim=-1)) * gate_score

# %%
class EdgeEnergyPredictor(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        
        # 1. Reactant의 기본 에너지 (Node 기반)
        # "이 분자가 원래 얼마나 불안정한가?"
        self.node_mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, 3) # [H, G, E]
        )
        
        # 2. 구조 변화에 따른 에너지 장벽 (Edge 기반)
        # "이 결합을 0.5A 늘리는 데 에너지가 얼마나 드는가?"
        # 입력: [Node_i, Node_j, 거리, 예측된_변화량, 게이트_점수]
        edge_input_dim = (hidden_dim * 2) + 1 + 1 + 1 
        self.edge_mlp = nn.Sequential(
            nn.Linear(edge_input_dim, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, 3) # [H, G, E] contribution per edge
        )

    def forward(self, h, edge_index, pos, gate_score, pred_delta_D, batch):
        row, col = edge_index
        
        # --- Part A: Global Reactant Feature (Node Pooling) ---
        # 분자 전체의 기본적인 성질 파악
        h_graph = global_add_pool(h, batch)
        base_energy = self.node_mlp(h_graph)
        
        # --- Part B: Transition State Cost (Edge Pooling) ---
        # 1. 엣지 특징 생성 (시작노드 + 끝노드 + 현재거리)
        dist = (pos[row] - pos[col]).norm(dim=-1, keepdim=True)
        
        # 2. 엣지 입력 벡터 구성: [h_i, h_j, dist, delta_D, gate]
        # 모델에게 "탄소-탄소 결합(h_i, h_j)이 1.5A(dist)인데, 
        # 0.2A(delta_D)만큼 늘어났고 매우 중요해(gate=1.0)"라는 정보를 줍니다.
        edge_feat = torch.cat([
            h[row], 
            h[col], 
            dist, 
            pred_delta_D, 
            gate_score
        ], dim=-1)
        
        # 3. 각 결합별 에너지 비용 계산
        edge_energy_contrib = self.edge_mlp(edge_feat)
        
        # 4. 중요하지 않은 결합(Gate=0)은 에너지 기여도 0으로 만듦
        # (반응에 참여 안 하는 결합은 에너지를 안 쓰니까)
        edge_energy_contrib = edge_energy_contrib * gate_score
        
        # 5. 분자 단위로 합치기 (Edge Sum Pooling)
        # batch[row]를 통해 각 엣지가 어떤 분자에 속하는지 알아냄
        edge_batch = batch[row]
        barrier_energy = global_add_pool(edge_energy_contrib, edge_batch)
        
        # 최종 에너지 = 반응물 기본 성질 + 활성화 장벽 비용
        return base_energy + barrier_energy

# %%
class MultiEnergyModel(nn.Module):
    def __init__(self, node_dim=5, hidden_dim=128, num_layers=3):
        super().__init__()
        self.encoder = DeepGCPNet(node_dim, hidden_dim, num_layers)
        self.gating = SigmoidGating(hidden_dim)
        self.struct_decoder = StructureDecoder(hidden_dim)
        
        # [교체됨] 새로운 에너지 예측기 사용
        self.energy_predictor = EdgeEnergyPredictor(hidden_dim)

    def forward(self, data):
        # 1. Encoding
        h = self.encoder(data.x, data.pos, data.edge_index)
        
        # 2. Gating (반응 중심 찾기)
        gate_map = self.gating(h, data.edge_index, data.pos)
        
        # 3. 구조 변화 예측 (Delta D)
        pred_delta_D = self.struct_decoder(h, data.edge_index, gate_map)
        
        # 4. 에너지 예측 (Node 정보 + Edge 변화 정보 모두 사용)
        pred_delta_E3 = self.energy_predictor(
            h, 
            data.edge_index, 
            data.pos, 
            gate_map, 
            pred_delta_D, 
            data.batch
        )
        
        return pred_delta_D, pred_delta_E3, gate_map

# %%
def train(h5_path, epochs=40, limit=None):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Device: {device}")
    
    try:
        dataset = ReactionDataset(h5_path, limit=limit)
    except Exception as e:
        print(f"❌ Error: {e}"); return None, None, None

    # --- Normalization Statistics ---
    print("Computing stats...")
    loader_stat = DataLoader(dataset, batch_size=128, shuffle=False)
    all_E = []
    HARTREE_TO_KCAL = 627.5
    for b in loader_stat:
        all_E.append(b.y_energy.view(-1, 3) * HARTREE_TO_KCAL)
    all_E = torch.cat(all_E, dim=0)
    y_mean = all_E.mean(dim=0).to(device)
    y_std = all_E.std(dim=0).to(device)
    print(f"Mean: {y_mean.cpu().numpy()}, Std: {y_std.cpu().numpy()}")

    loader = DataLoader(dataset, batch_size=32, shuffle=True) # 배치 사이즈 조금 증가
    
    # 모델 크기 키움 (Hidden 256, Layer 4)
    model = MultiEnergyModel(node_dim=5, hidden_dim=256, num_layers=4).to(device)
    optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=1e-5) # AdamW로 변경
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)
    
    history = {'loss': []}
    real_E3, pred_E3 = {'H':[], 'G':[], 'E':[]}, {'H':[], 'G':[], 'E':[]}
    
    print("\n[Start Deep Training]")
    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        pbar = tqdm(loader, desc=f"Epoch {epoch+1}/{epochs}", unit="batch")
        
        for batch in pbar:
            batch = batch.to(device)
            optimizer.zero_grad()
            
            pred_d, pred_e3, gate = model(batch)
            
            # Ground Truth
            dist_R = (batch.pos[batch.edge_index[0]] - batch.pos[batch.edge_index[1]]).norm(dim=-1, keepdim=True)
            dist_TS = (batch.y_pos[batch.edge_index[0]] - batch.y_pos[batch.edge_index[1]]).norm(dim=-1, keepdim=True)
            delta_d_target = dist_TS - dist_R
            
            # Energy Target (Normalized)
            e_target_kcal = batch.y_energy.view(-1, 3) * HARTREE_TO_KCAL
            e_target_norm = (e_target_kcal - y_mean) / y_std
            
            # --- Loss Calculation (Huber Loss 사용) ---
            loss_struct = F.smooth_l1_loss(pred_d, delta_d_target) # MSE -> Smooth L1
            loss_energy = F.smooth_l1_loss(pred_e3, e_target_norm) # MSE -> Smooth L1
            loss_gate = F.binary_cross_entropy(gate, (torch.abs(delta_d_target)>0.1).float())
            
            total_loss = loss_struct + loss_energy + loss_gate
            
            total_loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            
            epoch_loss += total_loss.item()
            pbar.set_postfix({'Loss': f"{total_loss.item():.4f}"})
            
            # Visualization Data
            if epoch == epochs - 1:
                r = e_target_kcal.detach().cpu().numpy()
                p_norm = pred_e3.detach().cpu() * y_std.cpu() + y_mean.cpu() # Restore
                p = p_norm.numpy()
                for i, k in enumerate(['H', 'G', 'E']):
                    real_E3[k].extend(r[:, i])
                    pred_E3[k].extend(p[:, i])
                    
        avg_loss = epoch_loss / len(loader)
        history['loss'].append(avg_loss)
        scheduler.step(avg_loss)

    return history, real_E3, pred_E3

# %%
if __name__ == "__main__":
    MY_H5_PATH = r"C:\Users\yeseo\OneDrive\OneDrive - personal\서류&파일\University of Seoul\연구\Code\RGD1_CHNO.h5"
    if os.path.exists(MY_H5_PATH):
        # 학습량과 모델 크기가 커졌으므로 limit를 2000~5000 정도로 늘려서 테스트해보세요
        hist, r_E3, p_E3 = train(MY_H5_PATH, epochs=40, limit=10000) 
        
        if hist:
            plt.figure(figsize=(15, 5))
            plt.subplot(1, 4, 1); plt.plot(hist['loss'], 'k-'); plt.title("Loss (Huber)")
            titles = ["Delta H", "Delta G", "Delta E"]
            colors = ['r', 'g', 'b']
            for i, k in enumerate(['H', 'G', 'E']):
                plt.subplot(1, 4, i+2)
                if len(r_E3[k]) > 0:
                    plt.scatter(r_E3[k], p_E3[k], alpha=0.5, color=colors[i], s=10)
                    mx = max(max(r_E3[k]), max(p_E3[k]))
                    mn = min(min(r_E3[k]), min(p_E3[k]))
                    plt.plot([mn, mx], [mn, mx], 'k--')
                plt.title(titles[i])
            plt.tight_layout()
            plt.show()
# Out:
# Device: cpu
# Computing stats...
# C:\Users\yeseo\anaconda3\envs\mlchem\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Mean: [69.403175 74.3915   72.29167 ], Std: [28.19911  26.560163 29.295467]
#
# [Start Deep Training]
# Epoch 1/40: 100%|████████████████████████████████████████████████████| 313/313 [31:56<00:00,  6.12s/batch, Loss=1.4112]
# Epoch 2/40: 100%|████████████████████████████████████████████████████| 313/313 [32:05<00:00,  6.15s/batch, Loss=1.0752]
# Epoch 3/40: 100%|████████████████████████████████████████████████████| 313/313 [31:38<00:00,  6.06s/batch, Loss=1.2053]
# Epoch 4/40: 100%|████████████████████████████████████████████████████| 313/313 [31:33<00:00,  6.05s/batch, Loss=1.2140]
# Epoch 6/40: 100%|████████████████████████████████████████████████████| 313/313 [31:21<00:00,  6.01s/batch, Loss=1.3873]
# Epoch 7/40: 100%|████████████████████████████████████████████████████| 313/313 [31:22<00:00,  6.01s/batch, Loss=1.3708]
# Epoch 8/40: 100%|████████████████████████████████████████████████████| 313/313 [31:18<00:00,  6.00s/batch, Loss=1.2396]
# Epoch 9/40: 100%|████████████████████████████████████████████████████| 313/313 [31:58<00:00,  6.13s/batch, Loss=1.5080]
# Epoch 10/40: 100%|███████████████████████████████████████████████████| 313/313 [31:04<00:00,  5.96s/batch, Loss=1.2135]
# Epoch 11/40: 100%|███████████████████████████████████████████████████| 313/313 [31:34<00:00,  6.05s/batch, Loss=1.2461]
# Epoch 12/40: 100%|███████████████████████████████████████████████████| 313/313 [31:23<00:00,  6.02s/batch, Loss=1.1903]
# Epoch 13/40: 100%|███████████████████████████████████████████████████| 313/313 [27:24<00:00,  5.25s/batch, Loss=1.3207]
# Epoch 14/40: 100%|███████████████████████████████████████████████████| 313/313 [31:24<00:00,  6.02s/batch, Loss=1.0612]
# Epoch 15/40: 100%|███████████████████████████████████████████████████| 313/313 [31:30<00:00,  6.04s/batch, Loss=1.0863]
# Epoch 16/40: 100%|███████████████████████████████████████████████████| 313/313 [31:28<00:00,  6.03s/batch, Loss=0.9662]
# Epoch 17/40: 100%|███████████████████████████████████████████████████| 313/313 [31:33<00:00,  6.05s/batch, Loss=1.1411]
# Epoch 18/40: 100%|███████████████████████████████████████████████████| 313/313 [31:16<00:00,  5.99s/batch, Loss=1.2801]
# Epoch 19/40: 100%|███████████████████████████████████████████████████| 313/313 [30:56<00:00,  5.93s/batch, Loss=1.0258]
# Epoch 20/40: 100%|███████████████████████████████████████████████████| 313/313 [28:47<00:00,  5.52s/batch, Loss=1.0046]
# Epoch 21/40: 100%|███████████████████████████████████████████████████| 313/313 [27:24<00:00,  5.26s/batch, Loss=1.1428]
# Epoch 22/40: 100%|███████████████████████████████████████████████████| 313/313 [27:55<00:00,  5.35s/batch, Loss=1.0201]
# Epoch 23/40: 100%|███████████████████████████████████████████████████| 313/313 [27:38<00:00,  5.30s/batch, Loss=0.9290]
# Epoch 24/40: 100%|███████████████████████████████████████████████████| 313/313 [27:52<00:00,  5.34s/batch, Loss=1.2118]
# Epoch 25/40: 100%|███████████████████████████████████████████████████| 313/313 [27:42<00:00,  5.31s/batch, Loss=1.0523]
# Epoch 34/40: 100%|███████████████████████████████████████████████████| 313/313 [28:10<00:00,  5.40s/batch, Loss=1.1764]
# Epoch 35/40: 100%|███████████████████████████████████████████████████| 313/313 [28:11<00:00,  5.40s/batch, Loss=1.0757]
# Epoch 36/40: 100%|███████████████████████████████████████████████████| 313/313 [28:17<00:00,  5.42s/batch, Loss=1.0640]
# Epoch 37/40: 100%|███████████████████████████████████████████████████| 313/313 [24:15<00:00,  4.65s/batch, Loss=0.9311]
# Epoch 38/40: 100%|███████████████████████████████████████████████████| 313/313 [21:07<00:00,  4.05s/batch, Loss=0.9552]
# Epoch 40/40: 100%|███████████████████████████████████████████████████| 313/313 [20:37<00:00,  3.95s/batch, Loss=0.9313]

# %%
import numpy as np

def print_evaluation_report(real_dict, pred_dict):
    """
    학습 결과(정답 vs 예측)를 받아서 MAE, RMSE, R2, MSE를 계산하고 출력합니다.
    """
    print("\n" + "="*75)
    print(f"   📊 FINAL PHYSICS-INFORMED MODEL PERFORMANCE REPORT (kcal/mol)")
    print("="*75)
    
    # 헤더 출력
    header = f"{'Energy Type':<15} | {'MAE':<10} | {'RMSE':<10} | {'MSE':<10} | {'R² Score':<10}"
    print(header)
    print("-" * 75)

    # H, G, E 각각에 대해 계산
    metrics = {}
    for key in ['H', 'G', 'E']:
        y_true = np.array(real_dict[key])
        y_pred = np.array(pred_dict[key])
        
        # 1. MAE (Mean Absolute Error)
        mae = np.mean(np.abs(y_true - y_pred))
        
        # 2. MSE (Mean Squared Error)
        mse = np.mean((y_true - y_pred)**2)
        
        # 3. RMSE (Root Mean Squared Error)
        rmse = np.sqrt(mse)
        
        # 4. R2 Score (Coefficient of Determination)
        ss_res = np.sum((y_true - y_pred)**2)
        ss_tot = np.sum((y_true - np.mean(y_true))**2)
        r2 = 1 - (ss_res / (ss_tot + 1e-8)) # 0으로 나누기 방지
        
        # 결과 저장
        metrics[key] = {'MAE': mae, 'RMSE': rmse, 'R2': r2}

        # 행 출력
        label = f"Delta {key} (Δ{key})"
        print(f"{label:<15} | {mae:<10.4f} | {rmse:<10.4f} | {mse:<10.4f} | {r2:<10.4f}")

    print("="*75)
    
    # [화학적 해석]
    # 화학적 정확도(Chemical Accuracy)는 보통 1 kcal/mol 이내를 말합니다.
    avg_mae = np.mean([metrics[k]['MAE'] for k in ['H', 'G', 'E']])
    print(f"⭐ Average MAE: {avg_mae:.4f} kcal/mol")
    
    if avg_mae < 2.5:
        print("✅ 모델이 물리 법칙(BEP, Hammond, Pauling)을 매우 잘 학습했습니다!")
        print("   (일반적인 DFT 계산 오차가 2~3 kcal/mol 수준임을 감안하면 훌륭합니다.)")
    elif avg_mae < 5.0:
        print("⚠️ 학습이 잘 되었으나, 일부 복잡한 반응에서 오차가 있습니다.")
    else:
        print("❌ 아직 과소적합 상태이거나 물리적 제약 조건이 더 필요합니다.")
    print("="*75 + "\n")

# ==============================================================================
# [실행 방법] main 블록 안에서 train()이 끝난 후 호출하세요
# ==============================================================================
if __name__ == "__main__":
    # 위에서 이미 train을 실행해서 r_E3, p_E3가 있다고 가정합니다.
    # 만약 변수가 메모리에 없다면 다시 학습을 돌려야 합니다.
    
    if 'r_E3' in locals() and 'p_E3' in locals():
        print_evaluation_report(r_E3, p_E3)
    else:
        print("먼저 train() 함수를 실행하여 r_E3, p_E3 변수를 생성해주세요.")
# Out:
# ===========================================================================
#    📊 FINAL PHYSICS-INFORMED MODEL PERFORMANCE REPORT (kcal/mol)
# ===========================================================================
# Energy Type     | MAE        | RMSE       | MSE        | R² Score
# ---------------------------------------------------------------------------
# Delta H (ΔH)    | 21.1683    | 26.5276    | 703.7126   | 0.1149
# Delta G (ΔG)    | 20.2932    | 25.3368    | 641.9517   | 0.0899
# Delta E (ΔE)    | 21.8157    | 27.3737    | 749.3171   | 0.1268
# ===========================================================================
# ⭐ Average MAE: 21.0924 kcal/mol
# ❌ 아직 과소적합 상태이거나 물리적 제약 조건이 더 필요합니다.
# ===========================================================================
